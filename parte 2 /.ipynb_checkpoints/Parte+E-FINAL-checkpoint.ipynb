# %%
#%load_ext snakeviz
# %matplotlib inline

# %%
#librerias utilitarias
from random import randint
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

# %%
#librerias Keras
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D, AveragePooling2D
from keras.optimizers import SGD, Adadelta, Adagrad
from keras.utils import np_utils

# %%
from utils.multi_gpu import make_parallel

# %%
# !nvidia-smi
# Out:
# Fri Jun 16 05:22:58 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 375.39                 Driver Version: 375.39                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 0000:00:17.0     Off |                    0 |
# | N/A   61C    P0    61W / 149W |      0MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla K80           Off  | 0000:00:18.0     Off |                    0 |
# | N/A   50C    P0    73W / 149W |      0MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla K80           Off  | 0000:00:19.0     Off |                    0 |
# | N/A   61C    P0    62W / 149W |      0MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla K80           Off  | 0000:00:1A.0     Off |                    0 |
# | N/A   50C    P0    73W / 149W |      0MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  Tesla K80           Off  | 0000:00:1B.0     Off |                    0 |
# | N/A   54C    P0    57W / 149W |      0MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  Tesla K80           Off  | 0000:00:1C.0     Off |                    0 |
# | N/A   42C    P0    71W / 149W |      0MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  Tesla K80           Off  | 0000:00:1D.0     Off |                    0 |
# | N/A   52C    P0    60W / 149W |      0MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  Tesla K80           Off  | 0000:00:1E.0     Off |                    0 |
# | N/A   45C    P0    71W / 149W |      0MiB / 11439MiB |     51%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID  Type  Process name                               Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Cargar Datos
# ___

# %%
train_data = sio.loadmat('data/train_32x32.mat')
test_data = sio.loadmat('data/test_32x32.mat')
X_train = train_data['X'].T
y_train = train_data['y'] - 1
X_test = test_data['X'].T
y_test = test_data['y'] - 1
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
n_classes = len(np.unique(y_train))
#print (np.unique(y_train))
X_train /= 255
X_test /= 255
Y_train = np_utils.to_categorical(y_train, n_classes)
Y_test = np_utils.to_categorical(y_test, n_classes)
print (X_train.shape)
print (X_test.shape)
print (Y_train.shape)
print (Y_test.shape)
# Out:
# (73257, 3, 32, 32)
# (26032, 3, 32, 32)
# (73257, 10)
# (26032, 10)

# %% [markdown]
# ### Preparar paralelismo
# ___
#
# Para parelizar la ejecución del modelo a nivel de datos se debe tener complir la siguiente relación:
#
# $$ \frac{\frac{datos-de-entrenamiento}{batches}}{Nº GPU`s} = 0$$
#
# Por quitamos 1 ejemplo de entreamiento y otro de test.

# %%
Y_test_parallel =np.delete(Y_test, 1, 0)
X_test_parallel =np.delete(X_test, 1, 0)
Y_train_parallel =np.delete(Y_train, 1, 0)
X_train_parallel =np.delete(X_train, 1, 0)
print (X_train_parallel.shape)
print (X_test_parallel.shape)
print (Y_train_parallel.shape)
print (Y_test_parallel.shape)
# Out:
# (73256, 3, 32, 32)
# (26031, 3, 32, 32)
# (73256, 10)
# (26031, 10)

# %% [markdown]
# Objetivo
# -----
# ### Modelo
# **(E)** Evalue el efecto de modificar el número de filtros para las capas convolucionales tanto en los tiempos de entrenamiento como en el desempeño de la red. Presente un gráfico o tabla resumen. Por simplicidad entre durante solo 10 epochs.
#
# Con el fin de poder realizar las pruebas de distintas configuraciones de las arquitecturas a evaluar, se modularizo la creación de un modelo así también el entrenamiento de estos modelos en dos funciones que podemos ver a comunicación:

# %%
def createModelo(n_channels,_nfilter_1,_nfilter_2, n_rows, n_cols,_con_1,_con_2,_pooling):
    model = Sequential()
    model.add(Convolution2D(_nfilter_1, _con_1, _con_1, border_mode='same', activation='relu',
                        input_shape=(n_channels, n_rows, n_cols)))
    model.add(MaxPooling2D(pool_size=(_pooling, _pooling)))
    model.add(Convolution2D(_nfilter_2, _con_2, _con_2, border_mode='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(_pooling, _pooling)))
    model.add(Flatten())
    model.add(Dense(20, activation='relu'))
    model.add(Dense(n_classes, activation='softmax'))
    #model.summary()
    return model

# %% [markdown]
# Los casos probados en la parte **D**,los modelos que presentaron mejores resultados fueron:
#
# |Nº|Capa convolucional 1 | Capa convolucional 2 |Capa de pooling
# | :-:| :-: | :-: | :-: | :-: |
# |1|2 |5|2|
# |4|5 | 7 | 3|
# |5|8 | 9| 2 |
#
# Usaremos estos modelos pero cambiando el numero de filtros de las capas convolucionales

# %%
#Parametros comunes
opt = Adagrad(lr=0.01, epsilon=1e-08, decay=0.0)
_size, n_channels, n_rows, n_cols = X_train_parallel.shape
epochs = 10
#batch_size= 32
batch_size=1280

# %% [markdown]
# ### Crear Modelos

# %%
#CASO 1
_con_1,_con_2,_pooling = 2,5,2
_nfilter_1,_nfilter_2=16,512
model_1 = createModelo(n_channels,_nfilter_1,_nfilter_2, n_rows, n_cols,_con_1,_con_2,_pooling)
model_1 = make_parallel(model_1, 8)
model_1.compile(loss='categorical_crossentropy', optimizer=opt,  metrics=['accuracy'])
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (2, 2), activation="relu", input_shape=(3, 32, 32..., padding="same")`
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (5, 5), activation="relu", padding="same")`
# /home/ubuntu/Tarea/parte2/utils/multi_gpu.py:44: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merged.append(merge(outputs, mode='concat', concat_axis=0))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/keras/legacy/layers.py:460: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /home/ubuntu/Tarea/parte2/utils/multi_gpu.py:46: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   return Model(input=model.inputs, output=merged)

# %%
#CASO 2
_con_1,_con_2,_pooling = 2,5,2
_nfilter_1,_nfilter_2=512,16
model_2 = createModelo(n_channels,_nfilter_1,_nfilter_2, n_rows, n_cols,_con_1,_con_2,_pooling)
model_2 = make_parallel(model_2, 8)
model_2.compile(loss='categorical_crossentropy', optimizer=opt,  metrics=['accuracy'])
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (2, 2), activation="relu", input_shape=(3, 32, 32..., padding="same")`
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (5, 5), activation="relu", padding="same")`
# /home/ubuntu/Tarea/parte2/utils/multi_gpu.py:44: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merged.append(merge(outputs, mode='concat', concat_axis=0))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/keras/legacy/layers.py:460: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /home/ubuntu/Tarea/parte2/utils/multi_gpu.py:46: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   return Model(input=model.inputs, output=merged)

# %%
#CASO 3
_con_1,_con_2,_pooling = 2,5,2
_nfilter_1,_nfilter_2=16,16
model_3 = createModelo(n_channels,_nfilter_1,_nfilter_2, n_rows, n_cols,_con_1,_con_2,_pooling)
model_3 = make_parallel(model_3, 8)
model_3.compile(loss='categorical_crossentropy', optimizer=opt,  metrics=['accuracy'])
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (2, 2), activation="relu", input_shape=(3, 32, 32..., padding="same")`
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (5, 5), activation="relu", padding="same")`
# /home/ubuntu/Tarea/parte2/utils/multi_gpu.py:44: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merged.append(merge(outputs, mode='concat', concat_axis=0))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/keras/legacy/layers.py:460: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /home/ubuntu/Tarea/parte2/utils/multi_gpu.py:46: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   return Model(input=model.inputs, output=merged)

# %%
#CASO 4
_con_1,_con_2,_pooling = 2,5,2
_nfilter_1,_nfilter_2=512,512
model_4 = createModelo(n_channels,_nfilter_1,_nfilter_2, n_rows, n_cols,_con_1,_con_2,_pooling)
model_4 = make_parallel(model_4, 8)
model_4.compile(loss='categorical_crossentropy', optimizer=opt,  metrics=['accuracy'])
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (2, 2), activation="relu", input_shape=(3, 32, 32..., padding="same")`
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (5, 5), activation="relu", padding="same")`
# /home/ubuntu/Tarea/parte2/utils/multi_gpu.py:44: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merged.append(merge(outputs, mode='concat', concat_axis=0))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/keras/legacy/layers.py:460: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /home/ubuntu/Tarea/parte2/utils/multi_gpu.py:46: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   return Model(input=model.inputs, output=merged)

# %% [markdown]
# ### Fit Modelos y tiempos de entrenamiento
#
# Solo considerando el tiempo de entrenamiento como indicador, podemos confirmar que modelos con mayor tamaño de filtros en las capas pooling implican mayor tiempo de entrenamiento y también el esquema  filtros de mayor tamaño en la capa inferiores presenta peores resultados, bueno esto ultimo se conoce dentro de las buenas practicas en las redes profundas. Esto ultimo con el fin de ir detectando características mas generales al principio del entrenamiento.
#
# Lo anterior lo podemos ver la siguiente tabla:
#
# <h3 align = 'center'> Tiempo de entrenamiento Modelos </h3>
#
# |Nº|Capa convolucional 1 | Capa convolucional 2 |Capa de pooling |_nfilter_1|_nfilter_2|Entrenamiento|
# | :-:| :-: | :-: | :-: | :-: |:-: |:-: |:-: |
# |1|2|5|2| 16|512|8min 42s|
# |2|2|5|3|512|16|21min 38s|
# |3|2|5 | 2|16|16|4min 6s |
# |4|2|5| 3 |512|512| 41min 23s|

# %%
# %%time
history_caso_1 = model_1.fit(X_train_parallel, Y_train_parallel, batch_size=batch_size, epochs=epochs, verbose=0,
          validation_data=(X_test, Y_test))
# Out:
# CPU times: user 6min 14s, sys: 2min 28s, total: 8min 42s
# Wall time: 1min 49s

# %%
# %%time
history_caso_2 = model_2.fit(X_train_parallel, Y_train_parallel, batch_size=batch_size, epochs=epochs, verbose=0,
          validation_data=(X_test, Y_test))
# Out:
# CPU times: user 15min 12s, sys: 6min 26s, total: 21min 38s
# Wall time: 5min 15s

# %%
# %%time
history_caso_3 = model_3.fit(X_train_parallel, Y_train_parallel, batch_size=batch_size, epochs=epochs, verbose=0,
          validation_data=(X_test, Y_test))
# Out:
# CPU times: user 2min 52s, sys: 1min 13s, total: 4min 6s
# Wall time: 45.2 s

# %%
# %%time
history_caso_4 = model_4.fit(X_train_parallel, Y_train_parallel, batch_size=batch_size, epochs=epochs, verbose=0,
          validation_data=(X_test, Y_test))
# Out:
# CPU times: user 31min 8s, sys: 10min 14s, total: 41min 23s
# Wall time: 10min 1s

# %% [markdown]
# ### Graficos de curvas
# ---

# %%
plt.figure(figsize=(15, 15))
plt.subplot(3, 2, 1)
plt.plot(history_caso_1.history['loss'])  
plt.plot(history_caso_1.history['val_loss'])  
plt.title('Loss - Caso 1')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['Entrenamiento', 'Test'], loc='upper left')  
plt.grid(True)

plt.subplot(3, 2, 2)
plt.plot(history_caso_2.history['loss'])  
plt.plot(history_caso_2.history['val_loss'])  
plt.title('Loss - Caso 2')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['Entrenamiento', 'Test'], loc='upper left')
plt.grid(True)

plt.subplot(3, 2, 3)
plt.plot(history_caso_3.history['loss'])  
plt.plot(history_caso_3.history['val_loss'])  
plt.title('Loss - Caso 3')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['Entrenamiento', 'Test'], loc='upper left')  
plt.grid(True)

plt.subplot(3, 2, 4)
plt.plot(history_caso_4.history['loss'])  
plt.plot(history_caso_4.history['val_loss'])  
plt.title('Loss - Caso 4')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['Entrenamiento', 'Test'], loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluar modelos
# ---

# %%
#%%time
scores_1 = model_1.evaluate(X_test, Y_test)
print("")
print("Accuracy del modelo Caso 1: %.2f%%" % (scores_1[1]*100))
print("Loss del modelo Caso 1: %.2f%%" % (scores_1[0]*100))
scores_2 = model_2.evaluate(X_test, Y_test)
print("")
print("Accuracy del modelo Caso 2: %.2f%%" % (scores_2[1]*100))
print("Loss del modelo Caso 2: %.2f%%" % (scores_2[0]*100))
scores_3 = model_3.evaluate(X_test, Y_test)
print("")
print("Accuracy del modelo Caso 3: %.2f%%" % (scores_3[1]*100))
print("Loss del modelo Caso 3: %.2f%%" % (scores_3[0]*100))
scores_4 = model_4.evaluate(X_test, Y_test)
print("")
print("Accuracy del modelo Caso 4: %.2f%%" % (scores_4[1]*100))
print("Loss del modelo Caso 4: %.2f%%" % (scores_4[0]*100))
# Out:
#  - ETA: 7s
#
# Accuracy del modelo Caso 1: 90.00%
# Loss del modelo Caso 1: 31.30%
# 26016/26032 [============================>.] - ETA: 0s
# Accuracy del modelo Caso 2: 94.11%
# Loss del modelo Caso 2: 16.75%
# 26032/26032 [==============================] - 4s
#
# Accuracy del modelo Caso 3: 94.22%
# Loss del modelo Caso 3: 15.84%
# 26032/26032 [==============================] - 43s
#
# Accuracy del modelo Caso 4: 83.19%
# Loss del modelo Caso 4: 269.51%
